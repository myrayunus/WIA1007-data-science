# %% [markdown]
# <a href="https://colab.research.google.com/github/myrayunus/WIA1007-data-science/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science
